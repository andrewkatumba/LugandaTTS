# %%
# !nvidia-smi -L
# !git clone https://github.com/coqui-ai/TTS
# %cd TTS
# !pip install -r requirements.txt
# !python setup.py install
# %cd ..
# Out:
# GPU 0: Tesla T4 (UUID: GPU-b0031612-4d1e-f20e-7735-3e306741e5e9)
# Cloning into 'TTS'...
# remote: Enumerating objects: 23599, done.
# remote: Total 23599 (delta 0), reused 0 (delta 0), pack-reused 23599
# Receiving objects: 100% (23599/23599), 127.66 MiB | 18.18 MiB/s, done.
# Resolving deltas: 100% (17137/17137), done.
# /content/TTS
# ...
# Compiling TTS/tts/utils/monotonic_align/core.pyx because it changed.
# [1/1] Cythonizing TTS/tts/utils/monotonic_align/core.pyx
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'build-lib' will not be supported in future versions. Please use the underscore name 'build_lib' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'build-dir' will not be supported in future versions. Please use the underscore name 'build_dir' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# ...

# %%
# !sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
# ...

# %%
# !mkdir new

# %%
# !git lfs install
# Out:
# Error: Failed to call git rev-parse --git-dir --show-toplevel: "fatal: not a git repository (or any of the parent directories): .git\n"
# Git LFS initialized.

# %%
# !git clone https://kakoozajerry:$token@github.com/KakoozaJerry/Speedy_Speech_Luganda_Model.git
# Out:
# Cloning into 'Speedy_Speech_Luganda_Model'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 0), reused 13 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.
# Filtering content: 100% (9/9), 1.41 GiB | 74.21 MiB/s, done.

# %%
# !pip install TTS

# %% [markdown]
# Speedy Speech

# %%
# !tts --text "Amaanyi poliisi g'etadde ku muyiggo." \
      --model_path /content/Speedy_Speech_Luganda_Model/checkpoint_370000.pth.tar \
      --config_path /content/Speedy_Speech_Luganda_Model/config.json \
      --out_path ./output1.wav
# Out:
#  > Using model: speedy_speech
#  > Using Griffin-Lim as no vocoder model defined
#  > Text: Amaanyi poliisi g'etadde ku muyiggo.
#  > Text splitted to sentences.
# ["Amaanyi poliisi g'etadde ku muyiggo."]
#  > Processing time: 1.546459674835205
#  > Real-time factor: 0.47561141249325306
#  > Saving output to ./output1.wav

# %%
# !wget https://raw.githubusercontent.com/KakoozaJerry/examples_page/gh-pages/sentences.json

# %%
import json

# %%
f = open('sentences.json')

# %%
data = json.load(f)

# %%
import argparse
import sys
from argparse import RawTextHelpFormatter

# pylint: disable=redefined-outer-name, unused-argument
from pathlib import Path

from TTS.utils.manage import ModelManager
from TTS.utils.synthesizer import Synthesizer

# %% [markdown]
# # load models
# ```
#     synthesizer = Synthesizer(
#         model_path,
#         config_path,
#         speakers_file_path,
#         language_ids_file_path,
#         vocoder_path,
#         vocoder_config_path,
#         encoder_path,
#         encoder_config_path,
#         args.use_cuda,
#     )
# ```

# %%
synthesizer = Synthesizer(
        "/content/drive/MyDrive/Emergent/train/Day23/44k_vits_train-February-01-2022_12+38PM-c63bb481/best_model_79300.pth.tar",
        "/content/drive/MyDrive/Emergent/train/Day23/44k_vits_train-February-01-2022_12+38PM-c63bb481/config.json",
        None,
        None,
        None,
        None,
        None,
        None,
        None,
    )
# Out:
#  > Using model: vits
#  > Using Griffin-Lim as no vocoder model defined

# %%
wav = synthesizer.tts("Gyebaleko", None, None, None)
# Out:
#  > Text splitted to sentences.
# ['Gyebaleko']
#  > Processing time: 2.3910739421844482
#  > Real-time factor: 1.6406267247064688

# %%
synthesizer.save_wav(wav, "/content/new.wav")

# %%
for i in data:
    if len(i['sentence']) >= 0:
      print(i['sentence'])
      wav = synthesizer.tts(i['sentence'], None, None, None)
      location = "/content/folder_four/" + "vits_44_" + str(i['id']) + '.wav'
      synthesizer.save_wav(wav, location)
    else:
      wav = synthesizer.tts("Tetwasobola kwogera sentensi eno", None, None, None)
      location = "/content/folder_four/" + "vits_44_" + str(i['id']) + '.wav'
      synthesizer.save_wav(wav, location)
# Out:
# Abaaliwo bonna baasooka ne basiriikirira nga beewuunya omulanga oguvudde mu musajja ayogereza mwannyinaabwe.
#  > Text splitted to sentences.
# ['Abaaliwo bonna baasooka ne basiriikirira nga beewuunya omulanga oguvudde mu musajja ayogereza mwannyinaabwe.']
#  > Processing time: 11.039472579956055
#  > Real-time factor: 1.4034198744755257
# Abakulembeze aba zigavumenti ezajja nga ziyita mu bwegugungo batera okuwandiika ebiwandiiko ebifaananako bwe bityo.
#  > Text splitted to sentences.
# ['Abakulembeze aba zigavumenti ezajja nga ziyita mu bwegugungo batera okuwandiika ebiwandiiko ebifaananako bwe bityo.']
#  > Processing time: 12.645638704299927
#  > Real-time factor: 1.343815463574302
# Abasajja bangi abajjanga okumwogereza naye mu bo abaasinga okusimba akaggo yali Sseggwanga, Ssewajjuba, mwanamulenzi Waffulungu n’omulala Wakkookootezi.
#  > Text splitted to sentences.
# ...

# %%
# %cd /content/folder_three/
# Out:
# /content/folder_three

# %%
# !zip -r ../folder_three.zip .
# Out:
#   adding: tacotron2_ddc_23.wav (deflated 37%)
#   adding: tacotron2_ddc_54.wav (deflated 41%)
#   adding: tacotron2_ddc_88.wav (deflated 26%)
#   adding: tacotron2_ddc_98.wav (deflated 18%)
#   adding: tacotron2_ddc_82.wav (deflated 19%)
#   adding: tacotron2_ddc_43.wav (deflated 18%)
#   adding: tacotron2_ddc_11.wav (deflated 35%)
#   adding: tacotron2_ddc_66.wav (deflated 25%)
#   adding: tacotron2_ddc_52.wav (deflated 22%)
#   adding: tacotron2_ddc_45.wav (deflated 29%)
#   adding: tacotron2_ddc_42.wav (deflated 18%)
#   adding: tacotron2_ddc_61.wav (deflated 20%)
#   adding: tacotron2_ddc_29.wav (deflated 33%)
#   adding: tacotron2_ddc_41.wav (deflated 20%)
#   adding: tacotron2_ddc_53.wav (deflated 22%)
#   adding: tacotron2_ddc_9.wav (deflated 18%)
#   adding: tacotron2_ddc_79.wav (deflated 21%)
#   adding: tacotron2_ddc_73.wav (deflated 18%)
#   adding: tacotron2_ddc_25.wav (deflated 27%)
#   adding: tacotron2_ddc_55.wav (deflated 27%)
# ...

# %%
f.close()

# %%
# !python3 /content/TTS/TTS/bin/synthesize.py --text "Musono ki ogwo ogw’enviiri?" --config_path /content/drive/MyDrive/Emergent/train/Day23/Vanilla_Tacotron2-February-07-2022_10+46AM-0000000/config.json --model_path /content/drive/MyDrive/Emergent/train/Day23/Vanilla_Tacotron2-February-07-2022_10+46AM-0000000/best_model.pth.tar --out_path ./output1.wav
# Out:
#  > Using model: tacotron2
#  > Model's reduction rate `r` is set to: 2
#  > Using Griffin-Lim as no vocoder model defined
#  > Text: Musono ki ogwo ogw’enviiri?
#  > Text splitted to sentences.
# ['Musono ki ogwo ogw’enviiri?']
#  > Processing time: 1.7806298732757568
#  > Real-time factor: 0.6284073096307689
#  > Saving output to ./output1.wav

# %%
# !tts --text "Musono ki ogwo ogw’enviiri?" \
      --model_path /content/drive/MyDrive/Emergent/train/Day23/Vanilla_Tacotron2-February-07-2022_10+46AM-0000000/best_model.pth.tar \
      --config_path /content/drive/MyDrive/Emergent/train/Day23/Vanilla_Tacotron2-February-07-2022_10+46AM-0000000/config.json \
      --out_path ./output1.wav
# Out:
#  > Using model: tacotron2
#  > Model's reduction rate `r` is set to: 2
#  > Using Griffin-Lim as no vocoder model defined
#  > Text: Musono ki ogwo ogw’enviiri?
#  > Text splitted to sentences.
# ['Musono ki ogwo ogw’enviiri?']
#  > Processing time: 2.5744166374206543
#  > Real-time factor: 0.9085449240577054
#  > Saving output to ./output1.wav
