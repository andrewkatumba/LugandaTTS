# %%
# !nvidia-smi -L
# !git clone https://github.com/coqui-ai/TTS
# %cd TTS
# !pip install -r requirements.txt
# !python setup.py install
# %cd ..
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-80b806f5-f7cd-9fa6-f505-2c4c492eeb64)
# Cloning into 'TTS'...
# remote: Enumerating objects: 23437, done.
# remote: Counting objects: 100% (4074/4074), done.
# remote: Compressing objects: 100% (1298/1298), done.
# remote: Total 23437 (delta 2935), reused 3609 (delta 2697), pack-reused 19363
# Receiving objects: 100% (23437/23437), 127.90 MiB | 26.71 MiB/s, done.
# Resolving deltas: 100% (16927/16927), done.
# /content/TTS
# ...
#      |████████████████████████████████| 183 kB 12.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 66.8 MB/s
# ...
#      |████████████████████████████████| 71 kB 11.7 MB/s
# ...
#      |████████████████████████████████| 124 kB 73.4 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 62.6 MB/s
# ...
#      |████████████████████████████████| 80 kB 12.5 MB/s
# ...
#      |████████████████████████████████| 284 kB 67.0 MB/s
# ...
#      |████████████████████████████████| 487 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 47.4 MB 1.2 MB/s
# ...

# %% [markdown]
# Data Used

# %%
# !unzip /content/drive/MyDrive/Emergent/recorded_dataset/dataset/total_dataset_as_of_day_23/Luganda_21h_40m_44kHz_LJSpeech.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/wavs/ba1ed7687f26c7b0a4d3e457f63d49aa.wav
#   inflating: /content/data/wavs/b91767f23f012fbcea4a1314b807e3ef.wav
#   inflating: /content/data/wavs/1eba8e464741f9f474f7f26a48290d51.wav
#   inflating: /content/data/wavs/3768b91ce1c2634402dc92be6803fe2b.wav
#   inflating: /content/data/wavs/14f22e1af94601b955926e435f5e7b9e.wav
#   inflating: /content/data/wavs/d380628cabf4e9f536277f174cc34163.wav
#   inflating: /content/data/wavs/ecda666dcc6f3b60b84f6d44d06ec14f.wav
#   inflating: /content/data/wavs/287567a24f4d65176dfdbfa95abd29bd.wav
#   inflating: /content/data/wavs/5122ec334322ff08992fa59919362daf.wav
#   inflating: /content/data/wavs/dcff61ba66a77b41b328a9a72061db4a.wav
#   inflating: /content/data/wavs/d3c7497eb75b7ee87c89f3cb8f61f733.wav
#   inflating: /content/data/wavs/6c0581ab17ffd6b86b10669e2b038b6e.wav
#   inflating: /content/data/wavs/f058c6d7e36103a90bd69be639ddb8fd.wav
# ...

# %% [markdown]
# ***Start Training***

# %%
# !CUDA_VISIBLE_DEVICES=0 python /content/drive/MyDrive/Emergent/train/Day23/train_vits.py
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:44100
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:2048
#  | > power:1.5
#  | > preemphasis:0.98
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:45
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:False
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:512
#  | > win_length:2048
#  | > Found 17131 files in /content/data
#  > Using CUDA:  True
#  > Number of GPUs:  1
#
#  > Model has 83181932 parameters
#
#  > EPOCH: 0/10000
# ...

# %% [markdown]
# ***Continue Training***

# %%
# !CUDA_VISIBLE_DEVICES=0 python /content/drive/MyDrive/Emergent/train/Day23/train_vits.py --continue_path /content/drive/MyDrive/Emergent/train/Day23/44k_vits_train-February-01-2022_11+59AM-c63bb481
# Out:
#  | > Max length sequence: 578190.0
#  | > Min length sequence: 39.0
#  | > Avg length sequence: 201003.74009433962
#  | > Num. instances discarded by max-min (max=500000, min=10000) seq limits: 10
#  | > Batch group size: 80.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
#  > TRAINING (2022-02-01 11:55:24)
# Exception ignored in: <function _releaseLock at 0x7f84c17755f0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 221, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt
# ^C
